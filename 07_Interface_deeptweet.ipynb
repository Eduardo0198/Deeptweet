# %% [markdown]
# #  **07: Interface - DeepTweet**
# ### José Eduardo Viveros Escamilla | A01710605

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import pickle

# ==========================
# 1. Load Models & Tokenizer
# ==========================

# Replace with real paths
v1_model = tf.keras.models.load_model("models/deeptweet_v1_base.h5")
v2_model = tf.keras.models.load_model("models/deeptweet_v2_modern.h5")
v3_model = tf.keras.models.load_model("models/deeptweet_v3_modern.h5")

# ===== CARGA DEL TOKENIZER =====
import pickle
with open("tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)
tokenizer.num_words

MAX_LEN = 50
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def predict_from_model(text, model):
    seq = tokenizer.texts_to_sequences([text])
    pad = pad_sequences(seq, maxlen=MAX_LEN)
    prob = model.predict(pad, verbose=0)[0][0]
    label = "positivo" if prob >= 0.5 else "negativo"
    return label, float(prob)

# %% [markdown]
# Comparacion de modelos con diferentes Tweets, en la parte de abajo puedes agregar el Tweets que gustes y tendras la prediccion de los 3 al mismo tiempo

# %%
def compare_models(text):
    out = {
    "v1_base": predict_from_model(text, v1_model),
    "v2_modern": predict_from_model(text, v2_model),
    "v3_live": predict_from_model(text, v3_model)
    }

    print("===== RESULTADO POR MODELO =====")
    for name, (lab, prob) in out.items():
        print(f"{name}: {lab} (prob={prob:.3f})")


    votes = [out[m][0] for m in out]
    final = "positivo" if votes.count("positivo") >= 2 else "negativo"


    print("\nPredicción final (votación):", final)
    return out

# Interfaz interactiva
# Aqui puedes escribir cualquier tweet para analizar con los 3 modelos
compare_models("Bro this update is so fire 🔥🔥🔥")
# Out:
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.525)
# v2_modern: negativo (prob=0.394)
# v3_live: negativo (prob=0.408)
#
# Predicción final (votación): negativo
# {'v1_base': ('positivo', 0.5252269506454468),
#  'v2_modern': ('negativo', 0.3943888247013092),
#  'v3_live': ('negativo', 0.40781867504119873)}

# %%
test_suite = {
    "positivos": [
        "I absolutely love this! Amazing work 🔥",
        "Best update ever, seriously impressive!",
        "This tool is saving me so much time 😄",
        "This update is insane, I love it",
        "Amazing performance, exceeded expectations",
        "I feel so happy using this feature",
        "The new design is beautiful 💖",
        "This is absolutely perfect",
        "What an incredible improvement",
        "This company keeps getting better and better!"
        ],
    "negativos": [
        "This is terrible, worst update ever.",
        "I'm so disappointed, what a mess.",
        "Absolutely horrible experience.",
        "This ruined my workflow.",
        "I hate this update.",
        "This is so frustrating.",
        "It keeps crashing, awful.",
        "What a disaster.",
        "Terrible service once again.",
        "Nothing works, I'm done with this."
        ],
    "sarcasmo": [
        "Oh great, another bug. Wonderful 🙄",
        "Amazing… totally not broken.",
        "Fantastic job… not.",
        "Sure, this update totally improved things 😒",
        "Yeah because this is EXACTLY what I needed… not",
        "Amazing work guys, really… 🥴",
        "Wow, such stability, much crash, very wow",
        "Oh of course it failed again, classic",
        "I just LOVE when things break for no reason 🙃",
        "Sure, take your time loading… it's not like I need it"
        ],
    "neutros": [
        "The model uses LSTMs for classification.",
        "The update was released yesterday.",
        "Training took around 2 hours on GPU.",
        "The dataset contains 10,000 samples.",
        "This is part of a research project.",
        "They announced a new version today.",
        "The event starts in 30 minutes.",
        "This algorithm is used in NLP tasks.",
        "The server was down for maintenance.",
        "This feature is currently in beta."
        ],
    "emocionales": [
        "I wish things were easier sometimes.",
        "I'm trying my best, but it's hard today.",
        "Feeling overwhelmed with everything.",
        "Today was surprisingly peaceful.",
        "Why do things feel so heavy lately?",
        "I really needed some good news today.",
        "Everything feels like too much.",
        "Trying to stay positive but it's exhausting.",
        "I miss feeling genuinely happy.",
        "Some days just hit harder than others."
        ],
    "tecnologia": [
        "OpenAI released a new version of GPT.",
        "The new API endpoint is finally out.",
        "The architecture is based on transformers.",
        "This model reaches a new SOTA benchmark.",
        "Inference time has been reduced significantly.",
        "Cloud usage increased after the update.",
        "The model was trained with 1.6M tweets.",
        "GPU utilization is at 95%.",
        "This framework is ideal for sentiment analysis.",
        "The deployment pipeline was improved."
        ],
    "tweets_modernos": [
        "Bro this update is INSANE 🔥🔥🔥",
        "Lmao this app is cooked 💀",
        "W update fr fr",
        "Not gonna lie, this slaps",
        "This is peak technology",
        "Huge W for the devs",
        "Sheeesh this works so good",
        "Massive L, everything broke",
        "This feature is so mid tbh",
        "Lowkey kinda impressed ngl"
        ],
    "confusos": [
        "I don't know if I like this or hate it.",
        "It works… sort of?",
        "Well that was something.",
        "I'm not sure how to feel about this.",
        "It’s okay… I guess.",
        "Mixed feelings tbh.",
        "Could be worse, could be better.",
        "Not bad but not good either.",
        "Hard to tell if it's an improvement.",
        "It feels weird, honestly."
        ],
    "extremos": [
        "🔥🔥🔥🔥🔥",
        "💀💀💀",
        "why.",
        "ok.",
        "I'm tired.",
        "lol",
        "no.",
        "pls stop",
        "help",
        "..."
        ]
}

# %% [markdown]
# Predicciones del del conjunto de Tweets de prueba
# Como podemos ver de igual forma se comparan los 3 modelos en disitintos temas, esto para eventualmente poder analizar el output y tener conclusiones generales de como se comporta cada uno, de igual forma todo esto estara reflejado en el reporte en l aprte de resultados

# %%
def run_stress_test():
    for category, examples in test_suite.items():
        print(f"\n=== {category.upper()} ===")
        for t in examples:
            print(f"\nTweet: {t}")
            compare_models(t)
            print("----------------------------------")
run_stress_test()
# Out:
# === POSITIVOS ===
#
# Tweet: I absolutely love this! Amazing work 🔥
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.694)
# v2_modern: positivo (prob=0.676)
# v3_live: positivo (prob=0.715)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Best update ever, seriously impressive!
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.641)
# v2_modern: positivo (prob=0.627)
# v3_live: positivo (prob=0.651)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: This tool is saving me so much time 😄
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.529)
# v2_modern: negativo (prob=0.315)
# v3_live: negativo (prob=0.363)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This update is insane, I love it
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.615)
# v2_modern: negativo (prob=0.439)
# v3_live: negativo (prob=0.453)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Amazing performance, exceeded expectations
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.558)
# v2_modern: positivo (prob=0.577)
# v3_live: positivo (prob=0.595)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: I feel so happy using this feature
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.734)
# v2_modern: positivo (prob=0.505)
# v3_live: positivo (prob=0.530)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: The new design is beautiful 💖
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.727)
# v2_modern: positivo (prob=0.677)
# v3_live: positivo (prob=0.715)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: This is absolutely perfect
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.804)
# v2_modern: positivo (prob=0.737)
# v3_live: positivo (prob=0.769)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: What an incredible improvement
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.748)
# v2_modern: positivo (prob=0.686)
# v3_live: positivo (prob=0.719)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: This company keeps getting better and better!
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.553)
# v2_modern: negativo (prob=0.414)
# v3_live: negativo (prob=0.417)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# === NEGATIVOS ===
#
# Tweet: This is terrible, worst update ever.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.065)
# v2_modern: negativo (prob=0.060)
# v3_live: negativo (prob=0.061)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: I'm so disappointed, what a mess.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.115)
# v2_modern: negativo (prob=0.098)
# v3_live: negativo (prob=0.098)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Absolutely horrible experience.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.177)
# v2_modern: negativo (prob=0.257)
# v3_live: negativo (prob=0.244)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This ruined my workflow.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.168)
# v2_modern: negativo (prob=0.197)
# v3_live: negativo (prob=0.193)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: I hate this update.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.188)
# v2_modern: negativo (prob=0.159)
# v3_live: negativo (prob=0.158)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This is so frustrating.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.221)
# v2_modern: negativo (prob=0.258)
# v3_live: negativo (prob=0.257)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: It keeps crashing, awful.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.073)
# v2_modern: negativo (prob=0.117)
# v3_live: negativo (prob=0.120)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: What a disaster.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.342)
# v2_modern: negativo (prob=0.340)
# v3_live: negativo (prob=0.343)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Terrible service once again.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.230)
# v2_modern: negativo (prob=0.209)
# v3_live: negativo (prob=0.204)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Nothing works, I'm done with this.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.487)
# v2_modern: negativo (prob=0.400)
# v3_live: negativo (prob=0.409)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# === SARCASMO ===
#
# Tweet: Oh great, another bug. Wonderful 🙄
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.681)
# v2_modern: positivo (prob=0.534)
# v3_live: positivo (prob=0.587)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Amazing… totally not broken.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.154)
# v2_modern: negativo (prob=0.224)
# v3_live: negativo (prob=0.224)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Fantastic job… not.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.633)
# v2_modern: positivo (prob=0.620)
# v3_live: positivo (prob=0.642)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Sure, this update totally improved things 😒
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.724)
# v2_modern: positivo (prob=0.600)
# v3_live: positivo (prob=0.642)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Yeah because this is EXACTLY what I needed… not
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.595)
# v2_modern: negativo (prob=0.258)
# v3_live: negativo (prob=0.267)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Amazing work guys, really… 🥴
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.607)
# v2_modern: positivo (prob=0.556)
# v3_live: positivo (prob=0.580)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Wow, such stability, much crash, very wow
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.396)
# v2_modern: negativo (prob=0.236)
# v3_live: negativo (prob=0.245)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Oh of course it failed again, classic
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.387)
# v2_modern: negativo (prob=0.282)
# v3_live: negativo (prob=0.306)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: I just LOVE when things break for no reason 🙃
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.578)
# v2_modern: negativo (prob=0.275)
# v3_live: negativo (prob=0.314)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Sure, take your time loading… it's not like I need it
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.472)
# v2_modern: negativo (prob=0.174)
# v3_live: negativo (prob=0.192)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# === NEUTROS ===
#
# Tweet: The model uses LSTMs for classification.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.579)
# v2_modern: negativo (prob=0.497)
# v3_live: positivo (prob=0.524)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: The update was released yesterday.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.392)
# v2_modern: negativo (prob=0.346)
# v3_live: negativo (prob=0.353)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Training took around 2 hours on GPU.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.477)
# v2_modern: negativo (prob=0.291)
# v3_live: negativo (prob=0.300)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: The dataset contains 10,000 samples.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.546)
# v2_modern: negativo (prob=0.385)
# v3_live: negativo (prob=0.382)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This is part of a research project.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.628)
# v2_modern: negativo (prob=0.430)
# v3_live: negativo (prob=0.445)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: They announced a new version today.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.556)
# v2_modern: negativo (prob=0.385)
# v3_live: negativo (prob=0.397)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: The event starts in 30 minutes.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.491)
# v2_modern: negativo (prob=0.399)
# v3_live: negativo (prob=0.420)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This algorithm is used in NLP tasks.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.497)
# v2_modern: negativo (prob=0.292)
# v3_live: negativo (prob=0.289)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: The server was down for maintenance.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.301)
# v2_modern: negativo (prob=0.203)
# v3_live: negativo (prob=0.201)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This feature is currently in beta.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.631)
# v2_modern: positivo (prob=0.522)
# v3_live: positivo (prob=0.537)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# === EMOCIONALES ===
#
# Tweet: I wish things were easier sometimes.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.458)
# v2_modern: negativo (prob=0.275)
# v3_live: negativo (prob=0.262)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: I'm trying my best, but it's hard today.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.324)
# v2_modern: negativo (prob=0.199)
# v3_live: negativo (prob=0.201)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Feeling overwhelmed with everything.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.364)
# v2_modern: negativo (prob=0.348)
# v3_live: negativo (prob=0.360)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Today was surprisingly peaceful.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.919)
# v2_modern: positivo (prob=0.884)
# v3_live: positivo (prob=0.903)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Why do things feel so heavy lately?
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.258)
# v2_modern: negativo (prob=0.179)
# v3_live: negativo (prob=0.183)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: I really needed some good news today.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.701)
# v2_modern: negativo (prob=0.475)
# v3_live: positivo (prob=0.503)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Everything feels like too much.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.299)
# v2_modern: negativo (prob=0.258)
# v3_live: negativo (prob=0.267)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Trying to stay positive but it's exhausting.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.483)
# v2_modern: negativo (prob=0.304)
# v3_live: negativo (prob=0.303)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: I miss feeling genuinely happy.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.330)
# v2_modern: negativo (prob=0.318)
# v3_live: negativo (prob=0.315)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Some days just hit harder than others.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.299)
# v2_modern: negativo (prob=0.180)
# v3_live: negativo (prob=0.182)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# === TECNOLOGIA ===
#
# Tweet: OpenAI released a new version of GPT.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.558)
# v2_modern: negativo (prob=0.383)
# v3_live: negativo (prob=0.398)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: The new API endpoint is finally out.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.709)
# v2_modern: positivo (prob=0.589)
# v3_live: positivo (prob=0.627)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: The architecture is based on transformers.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.354)
# v2_modern: negativo (prob=0.249)
# v3_live: negativo (prob=0.251)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This model reaches a new SOTA benchmark.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.573)
# v2_modern: negativo (prob=0.385)
# v3_live: negativo (prob=0.422)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Inference time has been reduced significantly.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.517)
# v2_modern: negativo (prob=0.390)
# v3_live: negativo (prob=0.392)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Cloud usage increased after the update.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.478)
# v2_modern: negativo (prob=0.316)
# v3_live: negativo (prob=0.315)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: The model was trained with 1.6M tweets.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.682)
# v2_modern: negativo (prob=0.475)
# v3_live: positivo (prob=0.537)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: GPU utilization is at 95%.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.551)
# v2_modern: negativo (prob=0.442)
# v3_live: negativo (prob=0.446)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This framework is ideal for sentiment analysis.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.599)
# v2_modern: negativo (prob=0.346)
# v3_live: negativo (prob=0.379)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: The deployment pipeline was improved.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.716)
# v2_modern: positivo (prob=0.602)
# v3_live: positivo (prob=0.636)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# === TWEETS_MODERNOS ===
#
# Tweet: Bro this update is INSANE 🔥🔥🔥
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.470)
# v2_modern: negativo (prob=0.362)
# v3_live: negativo (prob=0.375)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Lmao this app is cooked 💀
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.581)
# v2_modern: negativo (prob=0.397)
# v3_live: negativo (prob=0.413)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: W update fr fr
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.567)
# v2_modern: positivo (prob=0.585)
# v3_live: positivo (prob=0.595)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Not gonna lie, this slaps
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.504)
# v2_modern: negativo (prob=0.401)
# v3_live: negativo (prob=0.401)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This is peak technology
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.560)
# v2_modern: positivo (prob=0.508)
# v3_live: positivo (prob=0.512)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Huge W for the devs
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.608)
# v2_modern: negativo (prob=0.465)
# v3_live: negativo (prob=0.482)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Sheeesh this works so good
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.794)
# v2_modern: positivo (prob=0.674)
# v3_live: positivo (prob=0.679)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Massive L, everything broke
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.120)
# v2_modern: negativo (prob=0.178)
# v3_live: negativo (prob=0.184)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: This feature is so mid tbh
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.477)
# v2_modern: negativo (prob=0.401)
# v3_live: negativo (prob=0.401)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Lowkey kinda impressed ngl
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.602)
# v2_modern: positivo (prob=0.545)
# v3_live: positivo (prob=0.554)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# === CONFUSOS ===
#
# Tweet: I don't know if I like this or hate it.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.219)
# v2_modern: negativo (prob=0.073)
# v3_live: negativo (prob=0.073)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: It works… sort of?
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.557)
# v2_modern: negativo (prob=0.488)
# v3_live: positivo (prob=0.500)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: Well that was something.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.627)
# v2_modern: positivo (prob=0.571)
# v3_live: positivo (prob=0.574)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: I'm not sure how to feel about this.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.469)
# v2_modern: negativo (prob=0.220)
# v3_live: negativo (prob=0.233)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: It’s okay… I guess.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.434)
# v2_modern: negativo (prob=0.396)
# v3_live: negativo (prob=0.389)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Mixed feelings tbh.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.330)
# v2_modern: negativo (prob=0.382)
# v3_live: negativo (prob=0.382)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Could be worse, could be better.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.469)
# v2_modern: negativo (prob=0.439)
# v3_live: negativo (prob=0.433)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Not bad but not good either.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.413)
# v2_modern: negativo (prob=0.267)
# v3_live: negativo (prob=0.261)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: Hard to tell if it's an improvement.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.649)
# v2_modern: negativo (prob=0.378)
# v3_live: negativo (prob=0.380)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: It feels weird, honestly.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.274)
# v2_modern: negativo (prob=0.242)
# v3_live: negativo (prob=0.239)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# === EXTREMOS ===
#
# Tweet: 🔥🔥🔥🔥🔥
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.527)
# v2_modern: positivo (prob=0.576)
# v3_live: positivo (prob=0.586)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: 💀💀💀
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.527)
# v2_modern: positivo (prob=0.576)
# v3_live: positivo (prob=0.586)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: why.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.527)
# v2_modern: positivo (prob=0.576)
# v3_live: positivo (prob=0.586)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: ok.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.543)
# v2_modern: positivo (prob=0.572)
# v3_live: positivo (prob=0.586)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: I'm tired.
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.337)
# v2_modern: negativo (prob=0.400)
# v3_live: negativo (prob=0.409)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: lol
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.629)
# v2_modern: positivo (prob=0.639)
# v3_live: positivo (prob=0.650)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: no.
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.527)
# v2_modern: positivo (prob=0.576)
# v3_live: positivo (prob=0.586)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: pls stop
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.336)
# v2_modern: negativo (prob=0.360)
# v3_live: negativo (prob=0.364)
#
# Predicción final (votación): negativo
# ----------------------------------
#
# Tweet: help
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.492)
# v2_modern: positivo (prob=0.557)
# v3_live: positivo (prob=0.569)
#
# Predicción final (votación): positivo
# ----------------------------------
#
# Tweet: ...
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.579)
# v2_modern: positivo (prob=0.654)
# v3_live: positivo (prob=0.665)
#
# Predicción final (votación): positivo
# ----------------------------------

# %% [markdown]
# ##  1. Positivos
#
# La mayoría de frases positivas son clasificadas correctamente por los tres modelos.
# Sin embargo, algunos ejemplos positivos fueron clasificados como negativos por v2 y v3:
#
# * “This tool is saving me so much time 😄”
#
# * “This update is insane, I love it”
#
# * “This company keeps getting better and better!”
#
# Interpretación
#
# * Estos casos reflejan patrones del lenguaje moderno:
#
# * “insane” aparece tanto en elogios como críticas, creando ambigüedad.
#
# * Expresiones tipo “saving me time” son muy usadas irónicamente (“didn’t save me ANY time”).
#
# * Frases optimistas también se usan sarcásticamente, lo cual confunde al modelo moderno.
#
# Conclusión:
#
# Los modelos modernos (v2, v3) son más sensibles al sarcasmo ligero y a la ironía, lo cual es coherente con el lenguaje de Twitter 2020–2025.
#
# ##  2. Negativos
#
# * Todos los ejemplos claramente negativos fueron correctamente clasificados por los tres modelos.
#
# Conclusión:
#
# La representación del “espacio negativo” está muy bien aprendida en las tres versiones. Es el comportamiento más consistente de los modelos.
#
# ##  3. Sarcasmo
#
# Aquí se ve la diferencia más importante entre v1 y los modelos modernos.
#
# Hallazgos
#
#  * v1 (2009): falla mucho; interpreta sarcasmo como positivo.
#
#  * v2 y v3: captan sarcasmo moderado mejor y clasifican correctamente muchos casos.
#
# Ejemplos donde v1 falla y v2/v3 aciertan:
#
# * “Oh great, another bug. Wonderful 🙄”
#
# * “Sure, this update totally improved things 😒”
#
# Conclusión:
#
# v2 y v3 aprendieron los patrones modernos del sarcasmo:
# emojis 🙄😒, expresiones como “sure”, “not”, “classic”.
# Esto demuestra la evolución del lenguaje digital y el valor del fine-tuning moderno.
#
# ## 4. Neutros
#
# Muchos tweets neutros se clasifican como negativos, especialmente por v2 y v3.
#
# Interpretación
#
# Esto ocurre porque:
#
# * La clase “neutral” se eliminó durante la binarización.
#
# * En Twitter moderno, mensajes técnicos/neutros suelen acompañar quejas.
#
# Conclusión:
#
# Los modelos modernos tienen un sesgo negativo natural, aprendido del dataset de Kaggle + datasets modernos.
#
# ## 5. Emocionales
#
# Los modelos detectan muy bien:
#
#  * tristeza
#
#  * estrés
#
#  * agotamiento
#
#  * emociones implícitas
#
# Excepto frases ambiguas como:
#
# * “I really needed some good news today.”
#
# Conclusión:
#
# v3 demuestra excelente sensibilidad a frases emocionales negativas.
#
# ## 6. Tecnología
#
# Aquí se observa una diferencia clara entre épocas.
#
# Patrón observado
#
#  * v1 (2009): clasifica muchas frases técnicas como positivas.
#
#  * v2 y v3: suelen clasificarlas como negativas o ligeramente negativas.
#
# Causa:
#
# En 2009:
#
# * el discurso tecnológico era muy optimista,
#
# * términos técnicos aparecían en contextos positivos.
#
# En 2024–2025:
#
# * la comunidad tecnológica usa estos términos en debates críticos o polémicos.
#
# Conclusión:
#
# Este segmento evidencia cómo cambia el discurso tecnológico con el tiempo.
#
# ##  7. Tweets modernos (slang Gen-Z)
#
# Expresiones como:
#
# * INSANE
#
# * cooked
#
# * mid
#
# * W update
#
# * slaps
#
# * ngl
#
# * fr fr
#
# son completamente desconocidas para v1.
#
# * v2 y v3 los manejan mejor, pero aún hay ambigüedad.
#
# Conclusión:
#
# v3 entendió slang moderno, pero aún no domina modismos ambiguos o sarcásticos.
#
# ## 8. Confusos y extremos
#
# Los modelos fallan en:
#
# * mensajes muy cortos
#
# * solo emojis
#
# * expresiones sin contexto
#
# Ejemplos que se clasifican como positivos:
#
# * “💀💀💀”
#
# * “…”
#
# * “ok.”
#
# * “why.”
#
# Causa técnica
#
# Los LSTM:
#
# * no entienden semántica de emojis
#
# * no tienen contexto histórico
#
# * tratan texto muy corto como positivo por distribución del dataset
#
# Conclusión:
#
# Estas son limitaciones naturales de LSTMs.
# Modelos tipo BERT manejarían esto mucho mejor

# %% [markdown]
# De igual forma este es un codigo interactivo donde puedes agregar los ejemplos que mas sean interesantes, por si lo quieres probar para no correr necesariamente los 40 ejemplos

# %%
tweets = [
    "I hate this update",
    "This is amazing!",
    "Not sure how to feel about this one",
    "Lmao this app broke again 💀",
    "This is peak tech fr"
]

for t in tweets:
    print("\nTweet:", t)
    compare_models(t)
    print("---------------------")
# Out:
# Tweet: I hate this update
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.188)
# v2_modern: negativo (prob=0.159)
# v3_live: negativo (prob=0.158)
#
# Predicción final (votación): negativo
# ---------------------
#
# Tweet: This is amazing!
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.800)
# v2_modern: positivo (prob=0.749)
# v3_live: positivo (prob=0.776)
#
# Predicción final (votación): positivo
# ---------------------
#
# Tweet: Not sure how to feel about this one
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.434)
# v2_modern: negativo (prob=0.190)
# v3_live: negativo (prob=0.198)
#
# Predicción final (votación): negativo
# ---------------------
#
# Tweet: Lmao this app broke again 💀
# ===== RESULTADO POR MODELO =====
# v1_base: negativo (prob=0.217)
# v2_modern: negativo (prob=0.169)
# v3_live: negativo (prob=0.172)
#
# Predicción final (votación): negativo
# ---------------------
#
# Tweet: This is peak tech fr
# ===== RESULTADO POR MODELO =====
# v1_base: positivo (prob=0.556)
# v2_modern: negativo (prob=0.473)
# v3_live: negativo (prob=0.478)
#
# Predicción final (votación): negativo
# ---------------------

# %% [markdown]
# La comparación entre los tres modelos muestra una evolución clara en su capacidad para procesar lenguaje moderno.
#
# El modelo base (v1), entrenado con tweets del 2009, maneja bien textos directos pero falla en ironía, sarcasmo y jerga contemporánea.
#
# El modelo v2, afinado con un dataset moderno, incorpora patrones actuales del lenguaje digital, especialmente sarcasmo moderado y modismos recientes.
#
# El modelo v3, entrenado con tweets genuinos del 2024–2025, demuestra la mayor capacidad para interpretar expresiones ambiguas, lenguaje emocional y slang Gen-Z.
#
# Sin embargo, todos los modelos muestran un sesgo hacia clasificar textos neutrales como negativos, debido a la eliminación de la clase “neutral” durante la binarización.
#
# Finalmente, los LSTM presentan limitaciones claras en textos extremadamente cortos, emojis sin contexto y sarcasmo fuerte, lo cual sugiere que arquitecturas transformers serían una mejora natural para versiones futuras de DeepTweet.
